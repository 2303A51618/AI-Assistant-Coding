# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51618/AI-Assistant-Coding/blob/main/AI_ASST_13_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_rectangle_properties(length, width):
  """
  Calculates and prints the area and perimeter of a rectangle.

  Args:
    length (int or float): The length of the rectangle.
    width (int or float): The width of the rectangle.
  """
  area = length * width
  perimeter = 2 * (length + width)
  print(f"Area of Rectangle: {area}")
  print(f"Perimeter of Rectangle: {perimeter}")

# Calculate properties for different rectangles
calculate_rectangle_properties(5, 10)
calculate_rectangle_properties(7, 12)
calculate_rectangle_properties(10, 15)
# Out:
# Area of Rectangle: 50
# Perimeter of Rectangle: 30
# Area of Rectangle: 84
# Perimeter of Rectangle: 38
# Area of Rectangle: 150
# Perimeter of Rectangle: 50

# %%
names = ["Alice", "Bob", "Charlie", "David"]
search_names = ["Charlie", "Eve", "Bob"]

# Convert 'names' list to a set for efficient lookups
names_set = set(names)

for s in search_names:
    if s in names_set:
        print(f"{s} is in the list")
    else:
        print(f"{s} is not in the list")
# Out:
# Charlie is in the list
# Eve is not in the list
# Bob is in the list

# %%
def calculate_total_price(price, tax_rate):
  """
  Calculates the total price including tax.

  Args:
    price (int or float): The base price of the item.
    tax_rate (float): The tax rate (e.g., 0.18 for 18%).

  Returns:
    float: The total price including tax.
  """
  tax = price * tax_rate
  total = price + tax
  return total

# Calculate total prices for different base prices with a 18% tax rate
price1 = 250
total1 = calculate_total_price(price1, 0.18)
print(f"Total Price for {price1}: {total1}")

price2 = 500
total2 = calculate_total_price(price2, 0.18)
print(f"Total Price for {price2}: {total2}")
# Out:
# Total Price for 250: 295.0
# Total Price for 500: 590.0

# %%
PI = 3.14159
RADIUS = 7

print("Area of Circle:", PI * (RADIUS ** 2))
print("Circumference of Circle:", 2 * PI * RADIUS)
# Out:
# Area of Circle: 153.93791
# Circumference of Circle: 43.98226

# %%
base = 10
height = 20
area_of_triangle = base * height / 2
print(area_of_triangle)
# Out:
# 100.0
